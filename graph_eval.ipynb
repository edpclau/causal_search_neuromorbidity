# %%
# Causal Inference
import dowhy.gcm as gcm
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

# Data wrangling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dowhy.gcm.falsify import FalsifyConst, falsify_graph, plot_local_insights, run_validations, apply_suggestions
# Graph drawing
import networkx as nx

# %%
data = pd.read_csv('12hour.csv', na_values='*')
biomrkrs = pd.read_csv('./biomarker_attr.csv')
labs = biomrkrs.Biomarker.to_list()
labs.append('Neurologic Morbidity')
labs.append('Age')
data.columns = labs
# data = data.fillna(data.mean())
imputer = IterativeImputer(max_iter=10, random_state=0)
imputed_data = imputer.fit_transform(data)
data = pd.DataFrame(imputed_data, columns=data.columns)
data.head()
# Out:
#    Base deficit  Base excess  Bicarbonate  Blood urea nitrogen  Chloride  \
# 0     -4.943186    -0.096646    23.000000             7.000000 -0.000756
# 1     -5.589399    -0.113173    22.468451            12.929177 -0.000925
# 2      5.628605     4.000000    34.500000            17.370789 -0.001303
# 3     -8.580055    -0.592178    18.000000            20.064206 -0.001451
# 4     -1.675923     0.092489    24.763673            11.545403 -0.001232
#
#    Cisatracurium  C-Reactive Protein  Creatinine  CRRT Therapy Type   DBP  \
# 0            0.0           -0.001602  -50.000000                0.0  11.0
# 1            0.0           -0.000172   -0.165260                0.0  28.0
# 2            0.0           -0.000780    7.621208                0.0  22.0
# 3            0.0            0.001393   -3.778499                0.0  42.0
# 4            0.0           -0.001497   -0.405350                0.0  25.0
#
#    ...       SBP    Sodium  SpO2  Temperature  Ventilated  \
# 0  ...  0.019171  2.000000  97.0          1.0         0.0
# 1  ...  0.006519  0.000000  97.0          1.6         0.0
# 2  ...  0.013454  1.000000  97.0          0.6         1.0
# 3  ...  1.999583  0.000000  96.0          0.2         0.0
# 4  ...  0.016188  1.142838  98.0          0.4         1.0
#
#    Ventilator Make/Model     Weight  White blood cell count  \
# 0                   -1.0  -2.240879               10.314454
# 1                   -1.0   5.245110               19.300000
# 2                    0.0  31.358715               12.600000
# 3                   -1.0  46.977755               10.800000
# 4                    1.0   2.114946                8.929875
#
#    Neurologic Morbidity    Age
# 0                   0.0    1.0
# 1                   0.0   12.0
# 2                   0.0   12.0
# 3                   1.0  144.0
# 4                   0.0   12.0
#
# [5 rows x 47 columns]

# %%
# Draw and build a graph using a string
graph = nx.DiGraph(
    [
        ("Base excess", "Neurologic Morbidity"),
        ("Base deficit", "Neurologic Morbidity"),
        ("Bicarbonate", "Neurologic Morbidity"),
        ("Fentanyl", "Neurologic Morbidity"),
        ("Hemoglobin", "Neurologic Morbidity"),
        ("Lactate", "Neurologic Morbidity"),
        ("Lorazepam", "Neurologic Morbidity"),
        ("Midazolam", "Neurologic Morbidity"),
        ("Morphine", "Neurologic Morbidity"),
        ("Peds Coma Score", "Neurologic Morbidity"),
        ("Pupillary Reaction", "Neurologic Morbidity"),
        ("Sodium", "Neurologic Morbidity"),
        ("SpO2", "Neurologic Morbidity"),
        ("Temperature", "Neurologic Morbidity"),
    ]
)

# Draw the graph
plt.figure()
nx.draw(graph, with_labels=True)
plt.show()

causal_model = gcm.StructuralCausalModel(graph)
summary_auto_assignment = gcm.auto.assign_causal_mechanisms(causal_model, data)
gcm.fit(causal_model, data)
summary_evaluation = gcm.evaluate_causal_model(causal_model, data, compare_mechanism_baselines=True)
print(summary_evaluation)
# Out:
# Evaluated the performance of the causal mechanisms and the invertibility assumption of the causal mechanisms and the overall average KL divergence between generated and observed distribution and the graph structure. The results are as follows:
#
# ==== Evaluation of Causal Mechanisms ====
# The used evaluation metrics are:
# - KL divergence (only for root-nodes): Evaluates the divergence between the generated and the observed distribution.
# - Mean Squared Error (MSE): Evaluates the average squared differences between the observed values and the conditional expectation of the causal mechanisms.
# - Normalized MSE (NMSE): The MSE normalized by the standard deviation for better comparison.
# - R2 coefficient: Indicates how much variance is explained by the conditional expectations of the mechanisms. Note, however, that this can be misleading for nonlinear relationships.
# - F1 score (only for categorical non-root nodes): The harmonic mean of the precision and recall indicating the goodness of the underlying classifier model.
# - (normalized) Continuous Ranked Probability Score (CRPS): The CRPS generalizes the Mean Absolute Percentage Error to probabilistic predictions. This gives insights into the accuracy and calibration of the causal mechanisms.
# NOTE: Every metric focuses on different aspects and they might not consistently indicate a good or bad performance.
# We will mostly utilize the CRPS for comparing and interpreting the performance of the mechanisms, since this captures the most important properties for the causal model.
#
# --- Node Base excess
# - The KL divergence between generated and observed distribution is 0.2022856362197854.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Base deficit
# - The KL divergence between generated and observed distribution is 0.06751627189015372.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Bicarbonate
# - The KL divergence between generated and observed distribution is 0.3879750191216924.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Fentanyl
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Hemoglobin
# - The KL divergence between generated and observed distribution is 0.6999989894368743.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node Lactate
# - The KL divergence between generated and observed distribution is 0.09288843952706125.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Lorazepam
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Midazolam
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Morphine
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Peds Coma Score
# - The KL divergence between generated and observed distribution is 0.6862869565021751.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node Pupillary Reaction
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Sodium
# - The KL divergence between generated and observed distribution is 1.4796751137632522.
# The estimated KL divergence indicates some mismatches between the distributions.
#
# --- Node SpO2
# - The KL divergence between generated and observed distribution is 3.472435186427397.
# The estimated KL divergence indicates a significant mismatches between the distributions. Consider using models that better fit the distribution. However, also note that regardless of the model choice, intrinsically weak connections or very small signal to noise ratios will always lead to a poor fit.
#
# --- Node Temperature
# - The KL divergence between generated and observed distribution is 0.9562160924357819.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node Neurologic Morbidity
# - The MSE is 0.087354447928591.
# - The NMSE is 0.8920676514220801.
# - The R2 coefficient is 0.20410736234838014.
# - The normalized CRPS is 0.2633212264541633.
# The estimated CRPS indicates a good model performance.
# The mechanism is better or equally good than all 7 baseline mechanisms.
#
# ==== Evaluation of Invertible Functional Causal Model Assumption ====
#
# --- The model assumption for node Neurologic Morbidity is rejected with a p-value of 0.0 (after potential adjustment) and a significance level of 0.05.
# This implies that the model assumption might not be valid. This is, the relationship cannot be represent with this type of mechanism or there is a hidden confounder between the node and its parents.
#
# Note that these results are based on statistical independence tests, and the fact that the assumption was not rejected does not necessarily imply that it is correct. There is just no evidence against it.
#
# ==== Evaluation of Generated Distribution ====
# The overall average KL divergence between the generated and observed distribution is 0.5820388439524109
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# ==== Evaluation of the Causal Graph Structure ====
# +-------------------------------------------------------------------------------------------------------+
# |                                         Falsificaton Summary                                          |
# +-------------------------------------------------------------------------------------------------------+
# | The given DAG is informative because 2 / 50 of the permutations lie in the Markov                     |
# | equivalence class of the given DAG (p-value: 0.04).                                                   |
# | The given DAG violates 142/182 LMCs and is better than 44.0% of the permuted DAGs (p-value: 0.56).    |
# | Based on the provided significance level (0.2) and because the DAG is informative,                    |
# | we reject the DAG.                                                                                    |
# +-------------------------------------------------------------------------------------------------------+
#
# ==== NOTE ====
# Always double check the made model assumptions with respect to the graph structure and choice of causal mechanisms.
# All these evaluations give some insight into the goodness of the causal model, but should not be overinterpreted, since some causal relationships can be intrinsically hard to model. Furthermore, many algorithms are fairly robust against misspecifications or poor performances of causal mechanisms.

# %%
# Draw and build a graph using a string
graph = nx.DiGraph(
    [
        ("Base excess", "Neurologic Morbidity"),
        ("Fentanyl", "Neurologic Morbidity"),
        ("Hemoglobin", "Neurologic Morbidity"),
        ("Lactate", "Neurologic Morbidity"),
        ("Lorazepam", "Neurologic Morbidity"),
        ("Midazolam", "Neurologic Morbidity"),
        ("Morphine", "Neurologic Morbidity"),
        ("Peds Coma Score", "Neurologic Morbidity"),
        ("SpO2", "Neurologic Morbidity")
    ]
)

# Draw the graph
plt.figure()
nx.draw(graph, with_labels=True)
plt.show()

causal_model2 = gcm.StructuralCausalModel(graph)
summary_auto_assignment = gcm.auto.assign_causal_mechanisms(causal_model2, data)
gcm.fit(causal_model2, data)
summary_evaluation = gcm.evaluate_causal_model(causal_model2, data, compare_mechanism_baselines=True)
print(summary_evaluation)
# Out:
# Evaluated the performance of the causal mechanisms and the invertibility assumption of the causal mechanisms and the overall average KL divergence between generated and observed distribution and the graph structure. The results are as follows:
#
# ==== Evaluation of Causal Mechanisms ====
# The used evaluation metrics are:
# - KL divergence (only for root-nodes): Evaluates the divergence between the generated and the observed distribution.
# - Mean Squared Error (MSE): Evaluates the average squared differences between the observed values and the conditional expectation of the causal mechanisms.
# - Normalized MSE (NMSE): The MSE normalized by the standard deviation for better comparison.
# - R2 coefficient: Indicates how much variance is explained by the conditional expectations of the mechanisms. Note, however, that this can be misleading for nonlinear relationships.
# - F1 score (only for categorical non-root nodes): The harmonic mean of the precision and recall indicating the goodness of the underlying classifier model.
# - (normalized) Continuous Ranked Probability Score (CRPS): The CRPS generalizes the Mean Absolute Percentage Error to probabilistic predictions. This gives insights into the accuracy and calibration of the causal mechanisms.
# NOTE: Every metric focuses on different aspects and they might not consistently indicate a good or bad performance.
# We will mostly utilize the CRPS for comparing and interpreting the performance of the mechanisms, since this captures the most important properties for the causal model.
#
# --- Node Base excess
# - The KL divergence between generated and observed distribution is 0.16920015546267153.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Fentanyl
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Hemoglobin
# - The KL divergence between generated and observed distribution is 0.6854004377160088.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node Lactate
# - The KL divergence between generated and observed distribution is 0.046152069762368964.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Lorazepam
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Midazolam
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Morphine
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Peds Coma Score
# - The KL divergence between generated and observed distribution is 0.7140017280035719.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node SpO2
# - The KL divergence between generated and observed distribution is 3.540979463398911.
# The estimated KL divergence indicates a significant mismatches between the distributions. Consider using models that better fit the distribution. However, also note that regardless of the model choice, intrinsically weak connections or very small signal to noise ratios will always lead to a poor fit.
#
# --- Node Neurologic Morbidity
# - The MSE is 0.10130295091791333.
# - The NMSE is 0.9604980366267268.
# - The R2 coefficient is 0.07733116425010286.
# - The normalized CRPS is 0.3063190490042846.
# The estimated CRPS indicates a good model performance.
# The mechanism is better or equally good than all 7 baseline mechanisms.
#
# ==== Evaluation of Invertible Functional Causal Model Assumption ====
#
# --- The model assumption for node Neurologic Morbidity is rejected with a p-value of 0.0 (after potential adjustment) and a significance level of 0.05.
# This implies that the model assumption might not be valid. This is, the relationship cannot be represent with this type of mechanism or there is a hidden confounder between the node and its parents.
#
# Note that these results are based on statistical independence tests, and the fact that the assumption was not rejected does not necessarily imply that it is correct. There is just no evidence against it.
#
# ==== Evaluation of Generated Distribution ====
# The overall average KL divergence between the generated and observed distribution is 0.8730582659286164
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# ==== Evaluation of the Causal Graph Structure ====
# +-------------------------------------------------------------------------------------------------------+
# |                                         Falsificaton Summary                                          |
# +-------------------------------------------------------------------------------------------------------+
# | The given DAG is informative because 7 / 50 of the permutations lie in the Markov                     |
# | equivalence class of the given DAG (p-value: 0.14).                                                   |
# | The given DAG violates 64/72 LMCs and is better than 8.0% of the permuted DAGs (p-value: 0.92).       |
# | Based on the provided significance level (0.2) and because the DAG is informative,                    |
# | we reject the DAG.                                                                                    |
# +-------------------------------------------------------------------------------------------------------+
#
# ==== NOTE ====
# Always double check the made model assumptions with respect to the graph structure and choice of causal mechanisms.
# All these evaluations give some insight into the goodness of the causal model, but should not be overinterpreted, since some causal relationships can be intrinsically hard to model. Furthermore, many algorithms are fairly robust against misspecifications or poor performances of causal mechanisms.

# %%
# Draw and build a graph using a string
graph = nx.DiGraph(
    [
        ("Base excess", "Neurologic Morbidity"),
        ("Base deficit", "Neurologic Morbidity"),
        ("Bicarbonate", "Neurologic Morbidity"),
        ("Fentanyl", "Neurologic Morbidity"),
        ("Hemoglobin", "Neurologic Morbidity"),
        ("Lactate", "Neurologic Morbidity"),
        ("Lorazepam", "Neurologic Morbidity"),
        ("Midazolam", "Neurologic Morbidity"),
        ("Morphine", "Neurologic Morbidity"),
        ("Peds Coma Score", "Neurologic Morbidity"),
        ("Pupillary Reaction", "Neurologic Morbidity"),
        ("Sodium", "Neurologic Morbidity"),
        ("Temperature", "Neurologic Morbidity"),
    ]
)

# Draw the graph
plt.figure()
nx.draw(graph, with_labels=True)
plt.show()


causal_model3 = gcm.StructuralCausalModel(graph)
summary_auto_assignment = gcm.auto.assign_causal_mechanisms(causal_model3, data)
gcm.fit(causal_model3, data)
summary_evaluation = gcm.evaluate_causal_model(causal_model3, data, compare_mechanism_baselines=True)
print(summary_evaluation)
# Out:
# Evaluated the performance of the causal mechanisms and the invertibility assumption of the causal mechanisms and the overall average KL divergence between generated and observed distribution and the graph structure. The results are as follows:
#
# ==== Evaluation of Causal Mechanisms ====
# The used evaluation metrics are:
# - KL divergence (only for root-nodes): Evaluates the divergence between the generated and the observed distribution.
# - Mean Squared Error (MSE): Evaluates the average squared differences between the observed values and the conditional expectation of the causal mechanisms.
# - Normalized MSE (NMSE): The MSE normalized by the standard deviation for better comparison.
# - R2 coefficient: Indicates how much variance is explained by the conditional expectations of the mechanisms. Note, however, that this can be misleading for nonlinear relationships.
# - F1 score (only for categorical non-root nodes): The harmonic mean of the precision and recall indicating the goodness of the underlying classifier model.
# - (normalized) Continuous Ranked Probability Score (CRPS): The CRPS generalizes the Mean Absolute Percentage Error to probabilistic predictions. This gives insights into the accuracy and calibration of the causal mechanisms.
# NOTE: Every metric focuses on different aspects and they might not consistently indicate a good or bad performance.
# We will mostly utilize the CRPS for comparing and interpreting the performance of the mechanisms, since this captures the most important properties for the causal model.
#
# --- Node Base excess
# - The KL divergence between generated and observed distribution is 0.18773281981780993.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Base deficit
# - The KL divergence between generated and observed distribution is 0.0825502558788213.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Bicarbonate
# - The KL divergence between generated and observed distribution is 0.37746628278295374.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Fentanyl
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Hemoglobin
# - The KL divergence between generated and observed distribution is 0.6396843733866621.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node Lactate
# - The KL divergence between generated and observed distribution is 0.059802689151948106.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Lorazepam
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Midazolam
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Morphine
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Peds Coma Score
# - The KL divergence between generated and observed distribution is 0.7145304677632967.
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# --- Node Pupillary Reaction
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Sodium
# - The KL divergence between generated and observed distribution is 1.4877496785844238.
# The estimated KL divergence indicates some mismatches between the distributions.
#
# --- Node Temperature
# - The KL divergence between generated and observed distribution is 0.0.
# The estimated KL divergence indicates an overall very good representation of the data distribution.
#
# --- Node Neurologic Morbidity
# - The MSE is 0.08950864831695707.
# - The NMSE is 0.903335237726463.
# - The R2 coefficient is 0.18385277944009665.
# - The normalized CRPS is 0.2699296794437185.
# The estimated CRPS indicates a good model performance.
# The mechanism is better or equally good than all 7 baseline mechanisms.
#
# ==== Evaluation of Invertible Functional Causal Model Assumption ====
#
# --- The model assumption for node Neurologic Morbidity is rejected with a p-value of 0.0 (after potential adjustment) and a significance level of 0.05.
# This implies that the model assumption might not be valid. This is, the relationship cannot be represent with this type of mechanism or there is a hidden confounder between the node and its parents.
#
# Note that these results are based on statistical independence tests, and the fact that the assumption was not rejected does not necessarily imply that it is correct. There is just no evidence against it.
#
# ==== Evaluation of Generated Distribution ====
# The overall average KL divergence between the generated and observed distribution is 0.6236130470918688
# The estimated KL divergence indicates a good representation of the data distribution, but might indicate some smaller mismatches between the distributions.
#
# ==== Evaluation of the Causal Graph Structure ====
# +-------------------------------------------------------------------------------------------------------+
# |                                         Falsificaton Summary                                          |
# +-------------------------------------------------------------------------------------------------------+
# | The given DAG is informative because 1 / 50 of the permutations lie in the Markov                     |
# | equivalence class of the given DAG (p-value: 0.02).                                                   |
# | The given DAG violates 122/156 LMCs and is better than 10.0% of the permuted DAGs (p-value: 0.90).    |
# | Based on the provided significance level (0.2) and because the DAG is informative,                    |
# | we reject the DAG.                                                                                    |
# +-------------------------------------------------------------------------------------------------------+
#
# ==== NOTE ====
# Always double check the made model assumptions with respect to the graph structure and choice of causal mechanisms.
# All these evaluations give some insight into the goodness of the causal model, but should not be overinterpreted, since some causal relationships can be intrinsically hard to model. Furthermore, many algorithms are fairly robust against misspecifications or poor performances of causal mechanisms.
